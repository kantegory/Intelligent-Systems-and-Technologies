# %%
import numpy 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
# add libs for neural network creating
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
# Out:
# Using TensorFlow backend.
# /home/kantegory/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kantegory/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kantegory/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# Read dataset
data = pd.read_excel("LSVT_voice_rehabilitation.xlsx", header=0)
binary_classes = pd.read_excel("LSVT_voice_rehabilitation.xlsx", header=0, sheet_name="Binary response")
seed = 5
numpy.random.seed(seed)

# %%
data.head()
# Out:
#    Jitter->F0_abs_dif  Jitter->F0_dif_percent  \
# 0            0.088112                0.041697
# 1            0.161798                0.057364
# 2            0.554508                0.642913
# 3            0.031089                0.027108
# 4            0.076177                0.039071
#
#    Jitter->F0_PQ5_classical_Schoentgen  Jitter->F0_PQ5_classical_Baken  \
# 0                             0.000480                   -3.723304e-06
# 1                             0.000677                    5.466365e-06
# 2                             0.007576                   -7.443871e-07
# 3                             0.000314                   -2.214722e-07
# 4                             0.000302                    2.732106e-05
#
#    Jitter->F0_PQ5_generalised_Schoentgen  Jitter->F0_abs0th_perturb  \
# 0                               0.000422                   2.458381
# 1                               0.000206                   2.592066
# ...

# %%
binary_classes.head()
# Out:
#    Binary class 1=acceptable, 2=unacceptable
# 0                                          1
# 1                                          2
# 2                                          2
# 3                                          1
# 4                                          2

# %%
data.columns
# Out:
# Index(['Jitter->F0_abs_dif', 'Jitter->F0_dif_percent',
#        'Jitter->F0_PQ5_classical_Schoentgen', 'Jitter->F0_PQ5_classical_Baken',
#        'Jitter->F0_PQ5_generalised_Schoentgen', 'Jitter->F0_abs0th_perturb',
#        'Jitter->F0_CV', 'Jitter->F0_TKEO_mean', 'Jitter->F0_TKEO_std',
#        'Jitter->F0_TKEO_prc5',
#        ...
#        'det_TKEO_std4_1_coef', 'det_TKEO_std4_2_coef', 'det_TKEO_std4_3_coef',
#        'det_TKEO_std4_4_coef', 'det_TKEO_std4_5_coef', 'det_TKEO_std4_6_coef',
#        'det_TKEO_std4_7_coef', 'det_TKEO_std4_8_coef', 'det_TKEO_std4_9_coef',
#        'det_TKEO_std4_10_coef'],
#       dtype='object', length=310)

# %%
prediction_var = data.columns
X = data[prediction_var].values
Y = binary_classes.values

# %%
def create_baseline():
    model = Sequential()
    model.add(Dense(10, input_dim=30, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasClassifier(build_fn=create_baseline, epochs=100, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
kfold = StratifiedKFold(n_splits=10, shuffle=True)
results = cross_val_score(pipeline, X, Y, cv=kfold)
print("Results: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# WARNING:tensorflow:From /home/kantegory/.local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# /home/kantegory/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Error when checking input: expected dense_1_input to have shape (30,) but got array with shape (310,)
#
#   FitFailedWarning)
# /home/kantegory/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...
